# %% [markdown]
# # Compare Models - Next Item (DKT vs LPKT vs DKVMN)

# %%
# !git clone -b improve/high-impact-training https://github.com/GuilhermeDesoler/ai-core.git
# %cd ai-core
# !pip install -q -r requirements.txt

# %%
# !python scripts/run_dkt_next_item_pipeline.py
# !python scripts/run_lpkt_next_item_pipeline.py
# !python scripts/run_dkvmn_pipeline.py

# %%
import json, matplotlib.pyplot as plt
import pandas as pd

def load_metrics(path):
    with open(path) as f:
        return json.load(f)

dkvmn = load_metrics('artifacts/dkvmn_next_item/metrics.json') if False else None
